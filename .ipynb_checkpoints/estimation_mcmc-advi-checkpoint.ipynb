# %%
# %matplotlib inline

import pymc3 as pm
from pymc3.ode import DifferentialEquation
import numpy as np
import matplotlib.pyplot as plt
import seir_func_point as seir_func
import map_functions
import arviz as az
import theano

plt.style.use('seaborn-darkgrid')

# %%
city = "rj"
time_stamp = 3 * 365
incidence_real = map_functions.get_cases(city=city)[1:time_stamp]
infected_percentage = incidence_real[0]/map_functions.pop_dict[city]

# %%
seir = seir_func.seir()

# %%
seir_model = DifferentialEquation(
    func=seir.derivate,
    times=np.arange(1, time_stamp, 1),
    n_states=10,
    n_theta=16,
    t0=0,
)

# %%
with pm.Model() as model4:
    sigma = pm.HalfCauchy('sigma', 1, shape=1)

    # Distribuições a priori
    # R0 é limitada inferiormente em 1 para sempre termos uma epidemia.
    SH = pm.Uniform("SH", 0, 1, testval = 0.4891611167313461,)
    IH = infected_percentage
    EH = infected_percentage
    RH = 1 - SH - 2 * infected_percentage
    
    
    a_t = pm.Uniform("$a(t)$", 0.5, 2, testval = 0.691410701905391)
    p_mh_t = pm.Uniform("$p_mh(t)$", 0.5, 2, testval = 1.5609791900930738)
    u_v = pm.Uniform("$u_v$", 0.5, 2, testval = 1.1218292459714525)
    k = pm.Uniform("$k$", 0.5, 2, testval = 1.0323746614550986)
    gamma = pm.Uniform("$\gamma$", 0.5, 2, testval = 0.5232776467454814)
    delta = pm.Uniform("$\delta$", 0.5, 2, testval = 0.9923266319695812)
    

    sir_curves = seir_model(y0=[
        1000, 0, 0.99, 0, 0.0, 
        SH, IH, EH, 
        RH, IH
    ], 
                           theta=[1, 1, a_t, 
                  1, p_mh_t, 
                  1, 1, u_v, 
                  1, 1, 1, k, 
                  1, gamma, 
                  delta, 1]
                           )

    incidence = pm.Gamma('incidence', 
                     mu=sir_curves[:,9], 
                     sigma=sigma, 
                     observed=incidence_real)
    
    #db = pm.backends.Text('database/traces.csv') # Salva as amostras e assim evita de manter tudo na memória
    
    fit = pm.fit(method="mcmc", n = 10)
    #trace = pm.sample(10, tune=1, cores=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-bbe67cb48bbb> in <module>
#      38     #db = pm.backends.Text('database/traces.csv') # Salva as amostras e assim evita de manter tudo na memória
#      39
# ---> 40     fit = pm.fit(method="mcmc", n = 10)
#      41     #trace = pm.sample(10, tune=1, cores=1)
#
# /usr/local/lib/python3.6/dist-packages/pymc3/variational/inference.py in fit(n, local_rv, method, model, random_seed, start, inf_kwargs, **kwargs)
#     827             inference = _select[method](model=model, **inf_kwargs)
#     828         else:
# --> 829             raise KeyError(f"method should be one of {set(_select.keys())} or Inference instance")
#     830     elif isinstance(method, Inference):
#     831         inference = method
#
# KeyError: "method should be one of {'nfvi', 'fullrank_advi', 'asvgd', 'advi', 'svgd'} or Inference instance"

# %%
pm.save_trace(tr1, 'advi.trace', overwrite=True)
# Out:
# 'advi.trace'

# %%
#inference    
tr1 = approx.sample(draws=10)
pm.plots.traceplot(tr1);    
pm.plot_posterior(tr1, color='LightSeaGreen');

plt.plot(approx.hist)

# %%
data = az.from_pymc3(trace=tr1)
data
# Out:
# /usr/local/lib/python3.6/dist-packages/arviz/data/io_pymc3.py:92: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   FutureWarning,
# Inference data with groups:
# 	> posterior
# 	> log_likelihood
# 	> observed_data

# %%
az.plot_posterior(data, round_to=2, hdi_prob=0.95)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0794e8d550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0794ea5b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0794e4d780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0794e73a90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0794e07550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0794e28860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0794dcfb70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0794df38d0>]],
#       dtype=object)
